# %% [markdown]
# <a href="https://colab.research.google.com/github/AfrohFauziah/Machine-Learning/blob/main/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Baca Data
file = 'https://www.econometrics.com/intro/SALES.txt'
data = pd.read_fwf(file, header=None, names=['Sales', 'Advertising'])
data
# Out:
#     Sales  Advertising
# 0    12.0         15.0
# 1    20.5         16.0
# 2    21.0         18.0
# 3    15.5         27.0
# 4    15.3         21.0
# 5    23.5         49.0
# 6    24.5         21.0
# 7    21.3         22.0
# 8    23.5         28.0
# 9    28.0         36.0
# 10   24.0         40.0
# 11   15.5          3.0
# 12   17.3         21.0
# 13   25.3         29.0
# 14   25.0         62.0
# 15   36.5         65.0
# 16   36.5         46.0
# 17   29.6         44.0
# 18   30.5         33.0
# 19   28.0         62.0
# 20   26.0         22.0
# 21   21.5         12.0
# 22   19.7         24.0
# 23   19.0          3.0
# 24   16.0          5.0
# 25   20.7         14.0
# 26   26.5         36.0
# 27   30.6         40.0
# 28   32.3         49.0
# 29   29.5          7.0
# 30   28.3         52.0
# 31   31.3         65.0
# 32   32.3         17.0
# 33   26.4          5.0
# 34   23.4         17.0
# 35   16.4          1.0

# %%
# Eksplorasi Data
print(data.head())
print(data.columns)
# Out:
#    Sales  Advertising
# 0   12.0         15.0
# 1   20.5         16.0
# 2   21.0         18.0
# 3   15.5         27.0
# 4   15.3         21.0
# Index(['Sales', 'Advertising'], dtype='object')

# %%
# Pastikan Nama Kolom yang Benar
data.columns = data.columns.str.strip()

# %%
# Pisahkan Data untuk Training dan Testing
X = data[['Sales']]
y = data['Advertising']

# %%
# Bangun Model Simple Regression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Prediksi
sales_targets = np.array([[50], [100], [150]])
advertising_preds = model.predict(sales_targets)
print("Prediksi Advertising untuk 50, 100, 150 sales:", advertising_preds)
# Out:
# Prediksi Advertising untuk 50, 100, 150 sales: [ 77.82756831 173.5759746  269.3243809 ]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Evaluasi Model
y_pred = model.predict(X)
rmse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# RMSE: 14.367119905549034
# R2 Score: 0.3978668208721431

# %%
# Visualisasi
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.title('Sales vs Advertising')
plt.xlabel('Sales')
plt.ylabel('Advertising')
plt.show()
